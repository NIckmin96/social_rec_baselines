# %%
import os
import pandas as pd 
import numpy as np
import torch

# %%
data_dir = os.path.join('data','yelp')
rating = pd.read_csv(os.path.join(data_dir, 'rating_org.csv'))
trust = pd.read_csv(os.path.join(data_dir, 'trustnetwork_org.csv'))

# %%
(rating.groupby('user_id')['product_id'].nunique()<3).sum()
# Out:
# 1469272

# %%
a = torch.rand(274292,10)
b = torch.rand(20901935,10)
# c = torch.rand(274292,1)
# d = torch.rand(274292,1)

# %%
(b.size(0)-a.size(0))*10*a.element_size()/1024/1024/1024
# Out:
# 0.7684395834803581

# %%
a.element_size() * a.numel()/1024/1024
# Out:
# 10.463409423828125
