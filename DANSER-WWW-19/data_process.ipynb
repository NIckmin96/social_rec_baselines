# %%
import pandas as pd
import pickle
import os

# %%
# sample dataset
with open(os.path.join('data', 'dataset.pkl'), 'rb') as f:
    train_sample = pickle.load(f)
    test_sample = pickle.load(f)
# Out:
# /tmp/ipykernel_3962672/3592066676.py:3: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   train_sample = pickle.load(f)
# /tmp/ipykernel_3962672/3592066676.py:4: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   test_sample = pickle.load(f)

# %%
print(len(train_sample), len(test_sample))
# Out:
# 531859 132965

# %%
with open(os.path.join('data', 'ciao_timestamp', 'dataset_42.pkl'), 'rb') as f:
    train = pickle.load(f)
    test = pickle.load(f)

# %%
print(len(train), len(test))
# Out:
# 225494 132212

# %%
uid, pid, rating = [],[],[]
for u,p,r in test:
    uid.append(u)
    pid.append(p)
    rating.append(r)
print(set(rating))
    
# uid, pid, rating = [],[],[]
# for u,p,r in train:
#     uid.append(u)
#     pid.append(p)
#     rating.append(r)
# print(set(rating))
# Out:
# {0, 1, 2, 3, 4, 5}

# %%
import numpy as np

# %%
np.where(np.array(rating)==0)[0]
# Out:
# array([ 56373,  56374,  56375, ..., 132209, 132210, 132211],
#       shape=(75839,))
