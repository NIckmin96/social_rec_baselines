# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/home/moon/Desktop/social_rec/SocialMF'

# %%
ciao_dir = os.path.join('data','ciao_timestamp')
rating = pd.read_csv(os.path.join(ciao_dir,'rating_org.csv'))
rating_train = pd.read_csv(os.path.join(ciao_dir, 'rating_train_42.csv'))
rating_test = pd.read_csv(os.path.join(ciao_dir, 'rating_test_42.csv'))

# %%
print(rating.rating.mean())
print(rating_train.rating.mean())
print(rating_test.rating.mean())

print(rating.rating.std())
# Out:
# 4.1608034186830745
# 4.160409737456655
# 4.160185414528856
# 1.061487137870453

# %%
epi_dir = os.path.join('data','epinions')
rating = pd.read_csv(os.path.join(epi_dir,'rating_org.csv'))
rating_train = pd.read_csv(os.path.join(epi_dir, 'rating_train_42.csv'))
rating_test = pd.read_csv(os.path.join(epi_dir, 'rating_test_42.csv'))

# %%
print(rating.rating.mean())
print(rating_train.rating.mean())
print(rating_test.rating.mean())

print(rating.rating.std())
# Out:
# 3.971266455375721
# 3.9698555934423174
# 3.963022226118978
# 1.1691752042414278

# %%
yelp_dir = os.path.join('data','yelp')
rating = pd.read_csv(os.path.join(yelp_dir,'rating_org.csv'))
print(rating.rating.mean())
print(rating.rating.std())
# Out:
# 3.7543950414832974
# 1.475763299401457
